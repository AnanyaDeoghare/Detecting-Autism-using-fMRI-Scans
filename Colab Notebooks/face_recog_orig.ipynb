# %%
! git clone https://Nusha:inceptionv3@gitlab.com/Nusha/abcdefghi
# Out:
# fatal: destination path 'abcdefghi' already exists and is not an empty directory.

# %%
import torch
import numpy as np
from torchvision import datasets
import torchvision.transforms as transforms
from torch.utils.data.sampler import SubsetRandomSampler

# %%
# how many samples per batch to load
batch_size = 64
# percentage of training set to use as validation
test_size = 0.3
valid_size = 0.1

# convert data to a normalized torch.FloatTensor
transform = transforms.Compose([
    transforms.RandomHorizontalFlip(),
    transforms.RandomRotation(20),
    transforms.Resize(size=(224,224)),
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
    ])

data = datasets.ImageFolder('abcdefghi/data_die',transform=transform)

# %%
#For test
num_data = len(data)
indices_data = list(range(num_data))
np.random.shuffle(indices_data)
split_tt = int(np.floor(test_size * num_data))
train_idx, test_idx = indices_data[split_tt:], indices_data[:split_tt]

#For Valid
num_train = len(train_idx)
indices_train = list(range(num_train))
np.random.shuffle(indices_train)
split_tv = int(np.floor(valid_size * num_train))
train_new_idx, valid_idx = indices_train[split_tv:],indices_train[:split_tv]


# define samplers for obtaining training and validation batches
train_sampler = SubsetRandomSampler(train_new_idx)
test_sampler = SubsetRandomSampler(test_idx)
valid_sampler = SubsetRandomSampler(valid_idx)

train_loader = torch.utils.data.DataLoader(data, batch_size=batch_size,
    sampler=train_sampler, num_workers=1)
valid_loader = torch.utils.data.DataLoader(data, batch_size=batch_size, 
    sampler=valid_sampler, num_workers=1)
test_loader = torch.utils.data.DataLoader(data, sampler = test_sampler, batch_size=batch_size, 
    num_workers=1)
classes = [0,1]

# %%
len(test_loader)*batch_size + len(valid_loader)*batch_size + len(train_loader)*batch_size
for batch in valid_loader:
    print(batch[0].size())
# Out:
# torch.Size([61, 3, 224, 224])

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# helper function to un-normalize and display an image
def imshow(img):
    img = img / 2 + 0.5  # unnormalize
    plt.imshow(np.transpose(img, (1, 2, 0)))  # convert from Tensor image
    
# obtain one batch of training images
dataiter = iter(train_loader)
images, labels = dataiter.next()
images = images.numpy() # convert images to numpy for display

# plot the images in the batch, along with the corresponding labels
fig = plt.figure(figsize=(10, 4))
# display 20 images
for idx in np.arange(10):
    ax = fig.add_subplot(2, 10/2, idx+1, xticks=[], yticks=[])
    imshow(images[idx])
    ax.set_title(classes[labels[idx]])

# %%
import torch.nn as nn
import torch.nn.functional as F
train_on_gpu = torch.cuda.is_available()
# define the CNN architecture
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        # convolutional layer
        self.conv1 = nn.Conv2d(3, 16, 5)   #Input = 224*224
        #self.conv2 = nn.Conv2d(16, 16, 5)
        self.conv3 = nn.Conv2d(16, 32, 5)   #Input = 220*220
        
        # max pooling layer
        self.pool = nn.MaxPool2d(2, 2)     #Input = 216*216, output = 108*108
        
        self.dropout = nn.Dropout(0.2)
        
        self.fc1 = nn.Linear(32*53*53 , 256)  
        self.fc2 = nn.Linear(256, 84)
        self.fc3 = nn.Linear(84, 2)
        self.softmax = nn.LogSoftmax(dim=1)
        


        
    def forward(self, x):
        # add sequence of convolutional and max pooling layers
        x = self.pool(F.relu(self.conv1(x)))# 224 -> 220 -> 110
        #x = self.pool(F.relu(self.conv2(x))) # 110 -> 106 -> 53
        x = self.pool(F.relu(self.conv3(x)))
        x = self.dropout(x)
        x = x.view(-1, 32*53*53)   #32*53*53
        x = F.relu(self.fc1(x))
        x = self.dropout(F.relu(self.fc2(x)))
        x = self.softmax(self.fc3(x))

        return x

# create a complete CNN
model = Net()
print(model)

# move tensors to GPU if CUDA is available
if train_on_gpu:
    model.cuda()
# Out:
# Net(
#   (conv1): Conv2d(3, 16, kernel_size=(5, 5), stride=(1, 1))
#   (conv3): Conv2d(16, 32, kernel_size=(5, 5), stride=(1, 1))
#   (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (dropout): Dropout(p=0.2)
#   (fc1): Linear(in_features=89888, out_features=256, bias=True)
#   (fc2): Linear(in_features=256, out_features=84, bias=True)
#   (fc3): Linear(in_features=84, out_features=2, bias=True)
#   (softmax): LogSoftmax()
# )

# %%
# Loss function
criterion = torch.nn.CrossEntropyLoss()
# Optimizer
optimizer = torch.optim.SGD(model.parameters(), lr = 0.003, momentum= 0.9)

# %%
# number of epochs to train the model
n_epochs = 400 # you may increase this number to train a final model

valid_loss_min = np.Inf # track change in validation loss

for epoch in range(1, n_epochs+1):

    # keep track of training and validation loss
    train_loss = 0.0
    valid_loss = 0.0
    
    ###################
    # train the model #
    ###################
    model.train()
    for data, target in train_loader:
        # move tensors to GPU if CUDA is available
        if train_on_gpu:
            data, target = data.cuda(), target.cuda()
        # clear the gradients of all optimized variables
        optimizer.zero_grad()
        # forward pass: compute predicted outputs by passing inputs to the model
        output = model(data)
        # calculate the batch loss
        loss = criterion(output, target)
        # backward pass: compute gradient of the loss with respect to model parameters
        loss.backward()
        # perform a single optimization step (parameter update)
        optimizer.step()
        # update training loss
        train_loss += loss.item()*data.size(0)
        
    ######################    
    # validate the model #
    ######################
    model.eval()
    for data, target in valid_loader:
        # move tensors to GPU if CUDA is available
        if train_on_gpu:
            data, target = data.cuda(), target.cuda()
        # forward pass: compute predicted outputs by passing inputs to the model
        output = model(data)
        # calculate the batch loss
        loss = criterion(output, target)
        # update average validation loss 
        valid_loss += loss.item()*data.size(0)
    
    # calculate average losses
    train_loss = train_loss/len(train_loader.dataset)
    valid_loss = valid_loss/len(valid_loader.dataset)
        
    # print training/validation statistics 
    print('Epoch: {} \tTraining Loss: {:.6f} \tValidation Loss: {:.6f}'.format(
        epoch, train_loss, valid_loss))
    
    # save model if validation loss has decreased
    if valid_loss <= valid_loss_min:
        print('Validation loss decreased ({:.6f} --> {:.6f}).  Saving model ...'.format(
        valid_loss_min,
        valid_loss))
        torch.save(model.state_dict(), 'model_cifar.pt')
        valid_loss_min = valid_loss
# Out:
# Epoch: 1 	Training Loss: 0.423163 	Validation Loss: 0.045150
# Validation loss decreased (inf --> 0.045150).  Saving model ...
# Epoch: 2 	Training Loss: 0.385589 	Validation Loss: 0.043956
# Validation loss decreased (0.045150 --> 0.043956).  Saving model ...
# Epoch: 3 	Training Loss: 0.378321 	Validation Loss: 0.044132
# Epoch: 4 	Training Loss: 0.376003 	Validation Loss: 0.043128
# Validation loss decreased (0.043956 --> 0.043128).  Saving model ...
# Epoch: 5 	Training Loss: 0.373722 	Validation Loss: 0.043703
# Epoch: 6 	Training Loss: 0.374420 	Validation Loss: 0.043504
# Epoch: 7 	Training Loss: 0.373137 	Validation Loss: 0.043868
# Epoch: 8 	Training Loss: 0.374237 	Validation Loss: 0.043427
# Epoch: 9 	Training Loss: 0.376755 	Validation Loss: 0.043552
# Epoch: 10 	Training Loss: 0.376685 	Validation Loss: 0.043302
# Epoch: 11 	Training Loss: 0.378784 	Validation Loss: 0.043931
# Epoch: 12 	Training Loss: 0.375827 	Validation Loss: 0.043469
# Epoch: 13 	Training Loss: 0.376972 	Validation Loss: 0.043500
# Epoch: 14 	Training Loss: 0.373824 	Validation Loss: 0.043567
# Epoch: 15 	Training Loss: 0.373735 	Validation Loss: 0.043461
# Epoch: 16 	Training Loss: 0.373376 	Validation Loss: 0.043747
# Epoch: 17 	Training Loss: 0.373094 	Validation Loss: 0.043596
# Epoch: 18 	Training Loss: 0.375970 	Validation Loss: 0.043571
# Epoch: 19 	Training Loss: 0.374993 	Validation Loss: 0.043372
# Epoch: 20 	Training Loss: 0.375779 	Validation Loss: 0.043693
# Epoch: 21 	Training Loss: 0.375849 	Validation Loss: 0.043400
# Epoch: 22 	Training Loss: 0.375151 	Validation Loss: 0.043530
# Epoch: 23 	Training Loss: 0.374845 	Validation Loss: 0.043586
# Epoch: 24 	Training Loss: 0.377347 	Validation Loss: 0.043523
# Epoch: 25 	Training Loss: 0.373381 	Validation Loss: 0.043594
# Epoch: 26 	Training Loss: 0.373127 	Validation Loss: 0.043606
# Epoch: 27 	Training Loss: 0.375971 	Validation Loss: 0.043502
# Epoch: 28 	Training Loss: 0.374776 	Validation Loss: 0.043407
# Epoch: 29 	Training Loss: 0.375423 	Validation Loss: 0.043508
# Epoch: 30 	Training Loss: 0.373691 	Validation Loss: 0.043560
# Epoch: 31 	Training Loss: 0.374815 	Validation Loss: 0.043462
# Epoch: 32 	Training Loss: 0.374058 	Validation Loss: 0.043547
# Epoch: 33 	Training Loss: 0.374540 	Validation Loss: 0.043508
# Epoch: 34 	Training Loss: 0.375545 	Validation Loss: 0.043687
# Epoch: 35 	Training Loss: 0.371737 	Validation Loss: 0.043473
# Epoch: 36 	Training Loss: 0.375158 	Validation Loss: 0.043473
# Epoch: 37 	Training Loss: 0.375826 	Validation Loss: 0.043640
# Epoch: 38 	Training Loss: 0.373436 	Validation Loss: 0.043498
# Epoch: 39 	Training Loss: 0.374725 	Validation Loss: 0.043456
# Epoch: 40 	Training Loss: 0.373525 	Validation Loss: 0.043509
# Epoch: 41 	Training Loss: 0.374188 	Validation Loss: 0.043427
# Epoch: 42 	Training Loss: 0.372777 	Validation Loss: 0.043502
# Epoch: 43 	Training Loss: 0.372531 	Validation Loss: 0.043524
# Epoch: 44 	Training Loss: 0.374496 	Validation Loss: 0.043699
# Epoch: 45 	Training Loss: 0.371976 	Validation Loss: 0.043504
# Epoch: 46 	Training Loss: 0.372439 	Validation Loss: 0.043586
# Epoch: 47 	Training Loss: 0.373956 	Validation Loss: 0.043722
# Epoch: 48 	Training Loss: 0.373446 	Validation Loss: 0.043554
# Epoch: 49 	Training Loss: 0.373442 	Validation Loss: 0.043508
# Epoch: 50 	Training Loss: 0.374321 	Validation Loss: 0.043525
# Epoch: 51 	Training Loss: 0.372869 	Validation Loss: 0.043584
# Epoch: 52 	Training Loss: 0.375232 	Validation Loss: 0.043539
# Epoch: 53 	Training Loss: 0.372223 	Validation Loss: 0.043591
# Epoch: 54 	Training Loss: 0.375663 	Validation Loss: 0.043460
# Epoch: 55 	Training Loss: 0.373129 	Validation Loss: 0.043838
# Epoch: 56 	Training Loss: 0.372972 	Validation Loss: 0.043287
# Epoch: 57 	Training Loss: 0.372395 	Validation Loss: 0.043458
# Epoch: 58 	Training Loss: 0.373717 	Validation Loss: 0.043799
# Epoch: 59 	Training Loss: 0.371200 	Validation Loss: 0.043360
# Epoch: 60 	Training Loss: 0.372689 	Validation Loss: 0.043579
# Epoch: 61 	Training Loss: 0.373319 	Validation Loss: 0.043629
# Epoch: 62 	Training Loss: 0.373976 	Validation Loss: 0.043509
# Epoch: 63 	Training Loss: 0.372980 	Validation Loss: 0.043593
# Epoch: 64 	Training Loss: 0.371513 	Validation Loss: 0.043804
# Epoch: 65 	Training Loss: 0.374162 	Validation Loss: 0.043842
# Epoch: 66 	Training Loss: 0.371696 	Validation Loss: 0.043610
# Epoch: 67 	Training Loss: 0.371539 	Validation Loss: 0.043608
# Epoch: 68 	Training Loss: 0.372403 	Validation Loss: 0.043288
# Epoch: 69 	Training Loss: 0.372298 	Validation Loss: 0.043333
# Epoch: 70 	Training Loss: 0.372783 	Validation Loss: 0.043773
# Epoch: 71 	Training Loss: 0.370898 	Validation Loss: 0.043342
# Epoch: 72 	Training Loss: 0.371444 	Validation Loss: 0.043639
# Epoch: 73 	Training Loss: 0.370923 	Validation Loss: 0.043792
# Epoch: 74 	Training Loss: 0.371226 	Validation Loss: 0.043846
# Epoch: 75 	Training Loss: 0.374014 	Validation Loss: 0.043480
# Epoch: 76 	Training Loss: 0.371902 	Validation Loss: 0.043865
# Epoch: 77 	Training Loss: 0.369125 	Validation Loss: 0.043504
# Epoch: 78 	Training Loss: 0.370175 	Validation Loss: 0.043734
# Epoch: 79 	Training Loss: 0.370534 	Validation Loss: 0.043787
# Epoch: 80 	Training Loss: 0.372819 	Validation Loss: 0.043455
# Epoch: 81 	Training Loss: 0.369751 	Validation Loss: 0.043553
# Epoch: 82 	Training Loss: 0.367314 	Validation Loss: 0.043558
# Epoch: 83 	Training Loss: 0.367313 	Validation Loss: 0.043638
# Epoch: 84 	Training Loss: 0.367566 	Validation Loss: 0.043777
# Epoch: 85 	Training Loss: 0.363912 	Validation Loss: 0.043431
# Epoch: 86 	Training Loss: 0.370491 	Validation Loss: 0.043829
# Epoch: 87 	Training Loss: 0.364475 	Validation Loss: 0.043533
# Epoch: 88 	Training Loss: 0.365602 	Validation Loss: 0.043778
# Epoch: 89 	Training Loss: 0.370475 	Validation Loss: 0.044246
# Epoch: 90 	Training Loss: 0.367156 	Validation Loss: 0.044353
# Epoch: 91 	Training Loss: 0.363027 	Validation Loss: 0.044080
# Epoch: 92 	Training Loss: 0.366155 	Validation Loss: 0.044039
# Epoch: 93 	Training Loss: 0.365998 	Validation Loss: 0.044543
# Epoch: 94 	Training Loss: 0.363334 	Validation Loss: 0.044181
# Epoch: 95 	Training Loss: 0.361560 	Validation Loss: 0.044252
# Epoch: 96 	Training Loss: 0.358034 	Validation Loss: 0.044012
# Epoch: 97 	Training Loss: 0.361535 	Validation Loss: 0.044542
# Epoch: 98 	Training Loss: 0.358797 	Validation Loss: 0.044451
# Epoch: 99 	Training Loss: 0.360312 	Validation Loss: 0.045051
# Epoch: 100 	Training Loss: 0.358538 	Validation Loss: 0.045708
# Epoch: 101 	Training Loss: 0.358198 	Validation Loss: 0.044635
# Epoch: 102 	Training Loss: 0.354856 	Validation Loss: 0.046160
# Epoch: 103 	Training Loss: 0.364758 	Validation Loss: 0.046206
# Epoch: 104 	Training Loss: 0.365082 	Validation Loss: 0.044552
# Epoch: 105 	Training Loss: 0.353858 	Validation Loss: 0.046885
# Epoch: 106 	Training Loss: 0.347774 	Validation Loss: 0.044644
# Epoch: 107 	Training Loss: 0.351283 	Validation Loss: 0.047129
# Epoch: 108 	Training Loss: 0.358051 	Validation Loss: 0.044419
# Epoch: 109 	Training Loss: 0.349104 	Validation Loss: 0.045074
# Epoch: 110 	Training Loss: 0.342867 	Validation Loss: 0.045895
# Epoch: 111 	Training Loss: 0.346297 	Validation Loss: 0.045864
# Epoch: 112 	Training Loss: 0.336495 	Validation Loss: 0.047105
# Epoch: 113 	Training Loss: 0.331326 	Validation Loss: 0.047803
# Epoch: 114 	Training Loss: 0.322162 	Validation Loss: 0.047597
# Epoch: 115 	Training Loss: 0.338519 	Validation Loss: 0.047799
# Epoch: 116 	Training Loss: 0.330518 	Validation Loss: 0.049355
# Epoch: 117 	Training Loss: 0.352108 	Validation Loss: 0.047170
# Epoch: 118 	Training Loss: 0.337014 	Validation Loss: 0.045889
# Epoch: 119 	Training Loss: 0.322586 	Validation Loss: 0.049706
# Epoch: 120 	Training Loss: 0.316514 	Validation Loss: 0.049465
# Epoch: 121 	Training Loss: 0.303635 	Validation Loss: 0.051710
# Epoch: 122 	Training Loss: 0.352013 	Validation Loss: 0.048971
# Epoch: 123 	Training Loss: 0.344724 	Validation Loss: 0.056900
# Epoch: 124 	Training Loss: 0.345754 	Validation Loss: 0.046017
# Epoch: 125 	Training Loss: 0.332517 	Validation Loss: 0.047863
# Epoch: 126 	Training Loss: 0.319008 	Validation Loss: 0.047506
# Epoch: 127 	Training Loss: 0.305996 	Validation Loss: 0.049610
# Epoch: 128 	Training Loss: 0.287995 	Validation Loss: 0.049296
# Epoch: 129 	Training Loss: 0.286751 	Validation Loss: 0.056938
# Epoch: 130 	Training Loss: 0.286705 	Validation Loss: 0.057550
# Epoch: 131 	Training Loss: 0.278239 	Validation Loss: 0.052285
# Epoch: 132 	Training Loss: 0.277903 	Validation Loss: 0.057751
# Epoch: 133 	Training Loss: 0.275981 	Validation Loss: 0.054727
# Epoch: 134 	Training Loss: 0.277014 	Validation Loss: 0.062908
# Epoch: 135 	Training Loss: 0.253432 	Validation Loss: 0.052465
# Epoch: 136 	Training Loss: 0.269562 	Validation Loss: 0.058318
# Epoch: 137 	Training Loss: 0.259876 	Validation Loss: 0.063812
# Epoch: 138 	Training Loss: 0.273837 	Validation Loss: 0.057202
# Epoch: 139 	Training Loss: 0.276919 	Validation Loss: 0.050704
# Epoch: 140 	Training Loss: 0.240432 	Validation Loss: 0.052018
# Epoch: 141 	Training Loss: 0.237529 	Validation Loss: 0.065436
# Epoch: 142 	Training Loss: 0.230718 	Validation Loss: 0.057638
# Epoch: 143 	Training Loss: 0.255763 	Validation Loss: 0.055252
# Epoch: 144 	Training Loss: 0.234759 	Validation Loss: 0.056794
# Epoch: 145 	Training Loss: 0.208603 	Validation Loss: 0.058296
# Epoch: 146 	Training Loss: 0.210883 	Validation Loss: 0.057089
# Epoch: 147 	Training Loss: 0.209115 	Validation Loss: 0.091582
# Epoch: 148 	Training Loss: 0.311824 	Validation Loss: 0.054445
# Epoch: 149 	Training Loss: 0.248199 	Validation Loss: 0.052336
# Epoch: 150 	Training Loss: 0.222481 	Validation Loss: 0.062736
# Epoch: 151 	Training Loss: 0.208955 	Validation Loss: 0.059805
# Epoch: 152 	Training Loss: 0.198255 	Validation Loss: 0.064328
# Epoch: 153 	Training Loss: 0.211666 	Validation Loss: 0.068736
# Epoch: 154 	Training Loss: 0.217344 	Validation Loss: 0.063918
# Epoch: 155 	Training Loss: 0.182171 	Validation Loss: 0.076274
# Epoch: 156 	Training Loss: 0.163627 	Validation Loss: 0.064261
# Epoch: 157 	Training Loss: 0.194357 	Validation Loss: 0.073124
# Epoch: 158 	Training Loss: 0.198702 	Validation Loss: 0.056645
# Epoch: 159 	Training Loss: 0.166866 	Validation Loss: 0.067414
# Epoch: 160 	Training Loss: 0.166389 	Validation Loss: 0.077396
# Epoch: 161 	Training Loss: 0.163118 	Validation Loss: 0.074647
# Epoch: 162 	Training Loss: 0.201382 	Validation Loss: 0.069810
# Epoch: 163 	Training Loss: 0.159241 	Validation Loss: 0.066237
# Epoch: 164 	Training Loss: 0.138461 	Validation Loss: 0.085778
# Epoch: 165 	Training Loss: 0.136803 	Validation Loss: 0.078466
# Epoch: 166 	Training Loss: 0.166290 	Validation Loss: 0.074941
# Epoch: 167 	Training Loss: 0.147655 	Validation Loss: 0.077366
# Epoch: 168 	Training Loss: 0.132698 	Validation Loss: 0.080771
# Epoch: 169 	Training Loss: 0.147870 	Validation Loss: 0.088262
# Epoch: 170 	Training Loss: 0.131410 	Validation Loss: 0.079620
# Epoch: 171 	Training Loss: 0.133998 	Validation Loss: 0.074670
# Epoch: 172 	Training Loss: 0.091185 	Validation Loss: 0.073275
# Epoch: 173 	Training Loss: 0.129924 	Validation Loss: 0.085089
# Epoch: 174 	Training Loss: 0.107027 	Validation Loss: 0.102867
# Epoch: 175 	Training Loss: 0.102062 	Validation Loss: 0.090215
# Epoch: 176 	Training Loss: 0.093159 	Validation Loss: 0.100708
# Epoch: 177 	Training Loss: 0.112706 	Validation Loss: 0.100338
# Epoch: 178 	Training Loss: 0.101599 	Validation Loss: 0.098894
# Epoch: 179 	Training Loss: 0.109621 	Validation Loss: 0.110043
# Epoch: 180 	Training Loss: 0.094206 	Validation Loss: 0.071772
# Epoch: 181 	Training Loss: 0.079779 	Validation Loss: 0.119536
# Epoch: 182 	Training Loss: 0.082789 	Validation Loss: 0.095616
# Epoch: 183 	Training Loss: 0.086907 	Validation Loss: 0.106019
# Epoch: 184 	Training Loss: 0.096820 	Validation Loss: 0.104787
# Epoch: 185 	Training Loss: 0.116801 	Validation Loss: 0.089297
# Epoch: 186 	Training Loss: 0.101766 	Validation Loss: 0.081439
# Epoch: 187 	Training Loss: 0.101660 	Validation Loss: 0.087291
# Epoch: 188 	Training Loss: 0.078779 	Validation Loss: 0.090821
# Epoch: 189 	Training Loss: 0.077495 	Validation Loss: 0.115918
# Epoch: 190 	Training Loss: 0.080876 	Validation Loss: 0.096338
# Epoch: 191 	Training Loss: 0.072798 	Validation Loss: 0.111192
# Epoch: 192 	Training Loss: 0.091620 	Validation Loss: 0.083124
# Epoch: 193 	Training Loss: 0.076205 	Validation Loss: 0.119334
# Epoch: 194 	Training Loss: 0.061967 	Validation Loss: 0.102919
# Epoch: 195 	Training Loss: 0.059416 	Validation Loss: 0.093940
# Epoch: 196 	Training Loss: 0.054708 	Validation Loss: 0.127578
# Epoch: 197 	Training Loss: 0.068661 	Validation Loss: 0.131794
# Epoch: 198 	Training Loss: 0.069739 	Validation Loss: 0.127331
# Epoch: 199 	Training Loss: 0.049024 	Validation Loss: 0.104110
# Epoch: 200 	Training Loss: 0.048186 	Validation Loss: 0.119974
# Epoch: 201 	Training Loss: 0.051459 	Validation Loss: 0.123513
# Epoch: 202 	Training Loss: 0.072401 	Validation Loss: 0.113338
# Epoch: 203 	Training Loss: 0.065262 	Validation Loss: 0.085885
# Epoch: 204 	Training Loss: 0.051835 	Validation Loss: 0.112333
# Epoch: 205 	Training Loss: 0.071737 	Validation Loss: 0.116828
# Epoch: 206 	Training Loss: 0.055154 	Validation Loss: 0.119961
# Epoch: 207 	Training Loss: 0.056613 	Validation Loss: 0.121051
# Epoch: 208 	Training Loss: 0.071678 	Validation Loss: 0.091619
# Epoch: 209 	Training Loss: 0.057492 	Validation Loss: 0.118949
# Epoch: 210 	Training Loss: 0.052999 	Validation Loss: 0.121554
# Epoch: 211 	Training Loss: 0.039040 	Validation Loss: 0.119323
# Epoch: 212 	Training Loss: 0.068940 	Validation Loss: 0.109010
# Epoch: 213 	Training Loss: 0.050436 	Validation Loss: 0.093825
# Epoch: 214 	Training Loss: 0.048474 	Validation Loss: 0.093800
# Epoch: 215 	Training Loss: 0.059666 	Validation Loss: 0.099091
# Epoch: 216 	Training Loss: 0.047690 	Validation Loss: 0.108317
# Epoch: 217 	Training Loss: 0.043889 	Validation Loss: 0.136806
# Epoch: 218 	Training Loss: 0.043704 	Validation Loss: 0.105654
# Epoch: 219 	Training Loss: 0.054713 	Validation Loss: 0.130592
# Epoch: 220 	Training Loss: 0.058528 	Validation Loss: 0.124109
# Epoch: 221 	Training Loss: 0.042432 	Validation Loss: 0.126941
# Epoch: 222 	Training Loss: 0.070345 	Validation Loss: 0.078310
# Epoch: 223 	Training Loss: 0.067694 	Validation Loss: 0.126374
# Epoch: 224 	Training Loss: 0.055310 	Validation Loss: 0.109063
# Epoch: 225 	Training Loss: 0.078929 	Validation Loss: 0.121251
# Epoch: 226 	Training Loss: 0.057079 	Validation Loss: 0.092639
# Epoch: 227 	Training Loss: 0.038217 	Validation Loss: 0.118738
# Epoch: 228 	Training Loss: 0.041832 	Validation Loss: 0.123403
# Epoch: 229 	Training Loss: 0.039320 	Validation Loss: 0.147600
# Epoch: 230 	Training Loss: 0.048775 	Validation Loss: 0.150966
# Epoch: 231 	Training Loss: 0.052246 	Validation Loss: 0.124167
# Epoch: 232 	Training Loss: 0.041434 	Validation Loss: 0.118764
# Epoch: 233 	Training Loss: 0.030771 	Validation Loss: 0.138266
# Epoch: 234 	Training Loss: 0.029435 	Validation Loss: 0.129998
# Epoch: 235 	Training Loss: 0.047048 	Validation Loss: 0.142654
# Epoch: 236 	Training Loss: 0.028186 	Validation Loss: 0.127480
# Epoch: 237 	Training Loss: 0.025963 	Validation Loss: 0.119983
# Epoch: 238 	Training Loss: 0.023750 	Validation Loss: 0.129411
# Epoch: 239 	Training Loss: 0.025333 	Validation Loss: 0.184220
# Epoch: 240 	Training Loss: 0.026086 	Validation Loss: 0.139861
# Epoch: 241 	Training Loss: 0.022938 	Validation Loss: 0.128995
# Epoch: 242 	Training Loss: 0.027114 	Validation Loss: 0.143969
# Epoch: 243 	Training Loss: 0.016937 	Validation Loss: 0.141563
# Epoch: 244 	Training Loss: 0.038724 	Validation Loss: 0.188538
# Epoch: 245 	Training Loss: 0.014575 	Validation Loss: 0.154194
# Epoch: 246 	Training Loss: 0.028503 	Validation Loss: 0.161229
# Epoch: 247 	Training Loss: 0.034574 	Validation Loss: 0.133531
# Epoch: 248 	Training Loss: 0.024564 	Validation Loss: 0.160044
# Epoch: 249 	Training Loss: 0.039372 	Validation Loss: 0.147468
# Epoch: 250 	Training Loss: 0.038199 	Validation Loss: 0.151276
# Epoch: 251 	Training Loss: 0.041758 	Validation Loss: 0.144072
# Epoch: 252 	Training Loss: 0.054385 	Validation Loss: 0.135695
# Epoch: 253 	Training Loss: 0.042593 	Validation Loss: 0.133159
# Epoch: 254 	Training Loss: 0.045408 	Validation Loss: 0.138435
# Epoch: 255 	Training Loss: 0.051086 	Validation Loss: 0.116619
# Epoch: 256 	Training Loss: 0.030495 	Validation Loss: 0.162673
# Epoch: 257 	Training Loss: 0.033883 	Validation Loss: 0.142439
# Epoch: 258 	Training Loss: 0.020405 	Validation Loss: 0.158786
# Epoch: 259 	Training Loss: 0.020789 	Validation Loss: 0.174738
# Epoch: 260 	Training Loss: 0.013138 	Validation Loss: 0.172627
# Epoch: 261 	Training Loss: 0.021595 	Validation Loss: 0.148250
# Epoch: 262 	Training Loss: 0.021100 	Validation Loss: 0.141129
# Epoch: 263 	Training Loss: 0.019359 	Validation Loss: 0.158122
# Epoch: 264 	Training Loss: 0.028292 	Validation Loss: 0.157836
# Epoch: 265 	Training Loss: 0.023162 	Validation Loss: 0.165815
# Epoch: 266 	Training Loss: 0.015631 	Validation Loss: 0.181475
# Epoch: 267 	Training Loss: 0.018483 	Validation Loss: 0.136722
# Epoch: 268 	Training Loss: 0.030943 	Validation Loss: 0.184035
# Epoch: 269 	Training Loss: 0.018712 	Validation Loss: 0.148838
# Epoch: 270 	Training Loss: 0.025339 	Validation Loss: 0.159037
# Epoch: 271 	Training Loss: 0.025413 	Validation Loss: 0.196853
# Epoch: 272 	Training Loss: 0.036767 	Validation Loss: 0.148434
# Epoch: 273 	Training Loss: 0.034919 	Validation Loss: 0.132967
# Epoch: 274 	Training Loss: 0.026032 	Validation Loss: 0.152646
# Epoch: 275 	Training Loss: 0.019615 	Validation Loss: 0.135953
# Epoch: 276 	Training Loss: 0.038306 	Validation Loss: 0.173077
# Epoch: 277 	Training Loss: 0.044807 	Validation Loss: 0.155105
# Epoch: 278 	Training Loss: 0.033755 	Validation Loss: 0.170195
# Epoch: 279 	Training Loss: 0.031909 	Validation Loss: 0.126803
# Epoch: 280 	Training Loss: 0.016925 	Validation Loss: 0.172828
# Epoch: 281 	Training Loss: 0.016735 	Validation Loss: 0.169369
# Epoch: 282 	Training Loss: 0.016912 	Validation Loss: 0.156549
# Epoch: 283 	Training Loss: 0.018511 	Validation Loss: 0.147616
# Epoch: 284 	Training Loss: 0.016030 	Validation Loss: 0.188174
# Epoch: 285 	Training Loss: 0.031807 	Validation Loss: 0.200859
# Epoch: 286 	Training Loss: 0.022732 	Validation Loss: 0.154721
# Epoch: 287 	Training Loss: 0.015067 	Validation Loss: 0.168475
# Epoch: 288 	Training Loss: 0.024261 	Validation Loss: 0.149809
# Epoch: 289 	Training Loss: 0.012686 	Validation Loss: 0.173319
# Epoch: 290 	Training Loss: 0.019994 	Validation Loss: 0.184224
# Epoch: 291 	Training Loss: 0.020158 	Validation Loss: 0.151152
# Epoch: 292 	Training Loss: 0.024781 	Validation Loss: 0.183203
# Epoch: 293 	Training Loss: 0.032819 	Validation Loss: 0.173219
# Epoch: 294 	Training Loss: 0.021816 	Validation Loss: 0.192925
# Epoch: 295 	Training Loss: 0.020446 	Validation Loss: 0.171672
# Epoch: 296 	Training Loss: 0.011094 	Validation Loss: 0.174041
# Epoch: 297 	Training Loss: 0.011279 	Validation Loss: 0.214429
# Epoch: 298 	Training Loss: 0.015234 	Validation Loss: 0.198223
# Epoch: 299 	Training Loss: 0.030251 	Validation Loss: 0.201912
# Epoch: 300 	Training Loss: 0.011118 	Validation Loss: 0.175491
# Epoch: 301 	Training Loss: 0.015557 	Validation Loss: 0.150543
# Epoch: 302 	Training Loss: 0.016915 	Validation Loss: 0.188631
# Epoch: 303 	Training Loss: 0.013760 	Validation Loss: 0.161826
# Epoch: 304 	Training Loss: 0.026672 	Validation Loss: 0.173954
# Epoch: 305 	Training Loss: 0.026095 	Validation Loss: 0.146126
# Epoch: 306 	Training Loss: 0.015333 	Validation Loss: 0.175363
# Epoch: 307 	Training Loss: 0.012563 	Validation Loss: 0.163939
# Epoch: 308 	Training Loss: 0.012454 	Validation Loss: 0.138991
# Epoch: 309 	Training Loss: 0.018788 	Validation Loss: 0.207866
# Epoch: 310 	Training Loss: 0.028958 	Validation Loss: 0.184949
# Epoch: 311 	Training Loss: 0.054694 	Validation Loss: 0.187307
# Epoch: 312 	Training Loss: 0.029196 	Validation Loss: 0.172314
# Epoch: 313 	Training Loss: 0.016604 	Validation Loss: 0.149525
# Epoch: 314 	Training Loss: 0.023690 	Validation Loss: 0.146747
# Epoch: 315 	Training Loss: 0.021444 	Validation Loss: 0.140344
# Epoch: 316 	Training Loss: 0.017370 	Validation Loss: 0.170449
# Epoch: 317 	Training Loss: 0.024159 	Validation Loss: 0.182250
# Epoch: 318 	Training Loss: 0.025185 	Validation Loss: 0.155958
# Epoch: 319 	Training Loss: 0.025366 	Validation Loss: 0.162714
# Epoch: 320 	Training Loss: 0.022007 	Validation Loss: 0.136742
# Epoch: 321 	Training Loss: 0.015343 	Validation Loss: 0.141692
# Epoch: 322 	Training Loss: 0.017231 	Validation Loss: 0.187021
# Epoch: 323 	Training Loss: 0.004726 	Validation Loss: 0.147635
# Epoch: 324 	Training Loss: 0.010215 	Validation Loss: 0.174486
# Epoch: 325 	Training Loss: 0.012826 	Validation Loss: 0.204177
# Epoch: 326 	Training Loss: 0.020203 	Validation Loss: 0.155432
# Epoch: 327 	Training Loss: 0.011866 	Validation Loss: 0.174667
# Epoch: 328 	Training Loss: 0.021045 	Validation Loss: 0.180910
# Epoch: 329 	Training Loss: 0.015097 	Validation Loss: 0.169276
# Epoch: 330 	Training Loss: 0.008792 	Validation Loss: 0.157405
# Epoch: 331 	Training Loss: 0.013719 	Validation Loss: 0.194819
# Epoch: 332 	Training Loss: 0.017516 	Validation Loss: 0.164918
# Epoch: 333 	Training Loss: 0.010218 	Validation Loss: 0.236072
# Epoch: 334 	Training Loss: 0.014552 	Validation Loss: 0.236899
# Epoch: 335 	Training Loss: 0.006354 	Validation Loss: 0.248077
# Epoch: 336 	Training Loss: 0.012832 	Validation Loss: 0.188821
# Epoch: 337 	Training Loss: 0.010691 	Validation Loss: 0.146013
# Epoch: 338 	Training Loss: 0.047299 	Validation Loss: 0.191239
# Epoch: 339 	Training Loss: 0.014725 	Validation Loss: 0.186205
# Epoch: 340 	Training Loss: 0.012808 	Validation Loss: 0.202976
# Epoch: 341 	Training Loss: 0.012613 	Validation Loss: 0.214115
# Epoch: 342 	Training Loss: 0.017345 	Validation Loss: 0.183377
# Epoch: 343 	Training Loss: 0.019422 	Validation Loss: 0.162066
# Epoch: 344 	Training Loss: 0.021222 	Validation Loss: 0.156634
# Epoch: 345 	Training Loss: 0.009054 	Validation Loss: 0.154744
# Epoch: 346 	Training Loss: 0.004052 	Validation Loss: 0.168309
# Epoch: 347 	Training Loss: 0.012735 	Validation Loss: 0.157170
# Epoch: 348 	Training Loss: 0.008180 	Validation Loss: 0.198599
# Epoch: 349 	Training Loss: 0.014228 	Validation Loss: 0.220603
# Epoch: 350 	Training Loss: 0.031697 	Validation Loss: 0.200050
# Epoch: 351 	Training Loss: 0.015718 	Validation Loss: 0.249170
# Epoch: 352 	Training Loss: 0.019049 	Validation Loss: 0.172506
# Epoch: 353 	Training Loss: 0.015944 	Validation Loss: 0.196546
# Epoch: 354 	Training Loss: 0.020442 	Validation Loss: 0.184616
# Epoch: 355 	Training Loss: 0.018090 	Validation Loss: 0.190418
# Epoch: 356 	Training Loss: 0.008481 	Validation Loss: 0.233182
# Epoch: 357 	Training Loss: 0.013409 	Validation Loss: 0.161080
# Epoch: 358 	Training Loss: 0.012408 	Validation Loss: 0.222157
# Epoch: 359 	Training Loss: 0.010568 	Validation Loss: 0.209943
# Epoch: 360 	Training Loss: 0.013287 	Validation Loss: 0.198509
# Epoch: 361 	Training Loss: 0.010468 	Validation Loss: 0.159426
# Epoch: 362 	Training Loss: 0.008301 	Validation Loss: 0.195286
# Epoch: 363 	Training Loss: 0.020327 	Validation Loss: 0.212922
# Epoch: 364 	Training Loss: 0.017035 	Validation Loss: 0.162121
# Epoch: 365 	Training Loss: 0.012200 	Validation Loss: 0.213919
# Epoch: 366 	Training Loss: 0.010475 	Validation Loss: 0.182895
# Epoch: 367 	Training Loss: 0.018338 	Validation Loss: 0.191344
# Epoch: 368 	Training Loss: 0.027529 	Validation Loss: 0.185795
# Epoch: 369 	Training Loss: 0.019254 	Validation Loss: 0.214080
# Epoch: 370 	Training Loss: 0.022207 	Validation Loss: 0.140118
# Epoch: 371 	Training Loss: 0.018262 	Validation Loss: 0.170211
# Epoch: 372 	Training Loss: 0.024523 	Validation Loss: 0.210910
# Epoch: 373 	Training Loss: 0.023633 	Validation Loss: 0.164546
# Epoch: 374 	Training Loss: 0.016252 	Validation Loss: 0.178311
# Epoch: 375 	Training Loss: 0.010838 	Validation Loss: 0.178394
# Epoch: 376 	Training Loss: 0.015232 	Validation Loss: 0.185224
# Epoch: 377 	Training Loss: 0.010975 	Validation Loss: 0.133167
# Epoch: 378 	Training Loss: 0.010126 	Validation Loss: 0.193396
# Epoch: 379 	Training Loss: 0.015036 	Validation Loss: 0.205165
# Epoch: 380 	Training Loss: 0.009567 	Validation Loss: 0.157171
# Epoch: 381 	Training Loss: 0.014842 	Validation Loss: 0.176331
# Epoch: 382 	Training Loss: 0.011990 	Validation Loss: 0.181447
# Epoch: 383 	Training Loss: 0.011986 	Validation Loss: 0.211828
# Epoch: 384 	Training Loss: 0.014654 	Validation Loss: 0.223308
# Epoch: 385 	Training Loss: 0.005844 	Validation Loss: 0.208621
# Epoch: 386 	Training Loss: 0.009315 	Validation Loss: 0.201669
# Epoch: 387 	Training Loss: 0.007311 	Validation Loss: 0.157491
# Epoch: 388 	Training Loss: 0.013356 	Validation Loss: 0.164310
# Epoch: 389 	Training Loss: 0.004456 	Validation Loss: 0.202746
# Epoch: 390 	Training Loss: 0.005123 	Validation Loss: 0.158395
# Epoch: 391 	Training Loss: 0.008630 	Validation Loss: 0.141802
# Epoch: 392 	Training Loss: 0.005646 	Validation Loss: 0.187863
# Epoch: 393 	Training Loss: 0.012259 	Validation Loss: 0.220736
# Epoch: 394 	Training Loss: 0.007596 	Validation Loss: 0.173294
# Epoch: 395 	Training Loss: 0.018589 	Validation Loss: 0.195159
# Epoch: 396 	Training Loss: 0.008127 	Validation Loss: 0.161345
# Epoch: 397 	Training Loss: 0.009444 	Validation Loss: 0.204315
# Epoch: 398 	Training Loss: 0.008613 	Validation Loss: 0.182783
# Epoch: 399 	Training Loss: 0.007784 	Validation Loss: 0.202330
# Epoch: 400 	Training Loss: 0.011060 	Validation Loss: 0.225826

# %%
# track test loss
test_loss = 0.0
class_correct = list(0. for i in range(2))
class_total = list(0. for i in range(2))

print('\n FR_orig \n')
print(n_epochs)

model.eval()
i=1
# iterate over test data
len(test_loader)
for data, target in test_loader:
    i=i+1
    if len(target)!=batch_size:
        continue
        
    # move tensors to GPU if CUDA is available
    if train_on_gpu:
        data, target = data.cuda(), target.cuda()
    # forward pass: compute predicted outputs by passing inputs to the model
    output = model(data)
    # calculate the batch loss
    loss = criterion(output, target)
    # update test loss 
    test_loss += loss.item()*data.size(0)
    # convert output probabilities to predicted class
    _, pred = torch.max(output, 1)    
    # compare predictions to true label
    correct_tensor = pred.eq(target.data.view_as(pred))
    correct = np.squeeze(correct_tensor.numpy()) if not train_on_gpu else np.squeeze(correct_tensor.cpu().numpy())
    # calculate test accuracy for each object class
#     print(target)
    
    for i in range(batch_size):       
        label = target.data[i]
        class_correct[label] += correct[i].item()
        class_total[label] += 1

# average test loss
test_loss = test_loss/len(test_loader.dataset)
print('Test Loss: {:.6f}\n'.format(test_loss))

for i in range(2):
    if class_total[i] > 0:
        print('Test Accuracy of %5s: %2d%% (%2d/%2d)' % (
            classes[i], 100 * class_correct[i] / class_total[i],
            np.sum(class_correct[i]), np.sum(class_total[i])))
    else:
        print('Test Accuracy of %5s: N/A (no training examples)' % (classes[i]))

print('\nTest Accuracy (Overall): %2d%% (%2d/%2d)' % (
    100. * np.sum(class_correct) / np.sum(class_total),
    np.sum(class_correct), np.sum(class_total)))
# Out:
#  FR_orig
#
# 400
# Test Loss: 0.823896
#
# Test Accuracy of     0: 95% (115/120)
# Test Accuracy of     1: 47% (64/136)
#
# Test Accuracy (Overall): 69% (179/256)
