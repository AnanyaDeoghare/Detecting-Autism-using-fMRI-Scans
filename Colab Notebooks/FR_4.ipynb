# %%
! git clone https://Nusha:inceptionv3@gitlab.com/Nusha/abcdefghi
# Out:
# fatal: destination path 'abcdefghi' already exists and is not an empty directory.

# %%
import torch
import numpy as np
from torchvision import datasets
import torchvision.transforms as transforms
from torch.utils.data.sampler import SubsetRandomSampler

# %%
# how many samples per batch to load
batch_size = 64
# percentage of training set to use as validation
test_size = 0.3
valid_size = 0.1

# convert data to a normalized torch.FloatTensor
transform = transforms.Compose([
    transforms.RandomHorizontalFlip(),
    transforms.RandomRotation(20),
    transforms.Resize(size=(224,224)),
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
    ])

data = datasets.ImageFolder('abcdefghi/data_die',transform=transform)

# %%
#For test
num_data = len(data)
indices_data = list(range(num_data))
np.random.shuffle(indices_data)
split_tt = int(np.floor(test_size * num_data))
train_idx, test_idx = indices_data[split_tt:], indices_data[:split_tt]

#For Valid
num_train = len(train_idx)
indices_train = list(range(num_train))
np.random.shuffle(indices_train)
split_tv = int(np.floor(valid_size * num_train))
train_new_idx, valid_idx = indices_train[split_tv:],indices_train[:split_tv]


# define samplers for obtaining training and validation batches
train_sampler = SubsetRandomSampler(train_new_idx)
test_sampler = SubsetRandomSampler(test_idx)
valid_sampler = SubsetRandomSampler(valid_idx)

train_loader = torch.utils.data.DataLoader(data, batch_size=batch_size,
    sampler=train_sampler, num_workers=1)
valid_loader = torch.utils.data.DataLoader(data, batch_size=batch_size, 
    sampler=valid_sampler, num_workers=1)
test_loader = torch.utils.data.DataLoader(data, sampler = test_sampler, batch_size=batch_size, 
    num_workers=1)
classes = [0,1]

# %%
len(test_loader)*batch_size + len(valid_loader)*batch_size + len(train_loader)*batch_size
for batch in valid_loader:
    print(batch[0].size())
# Out:
# torch.Size([61, 3, 224, 224])

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# helper function to un-normalize and display an image
def imshow(img):
    img = img / 2 + 0.5  # unnormalize
    plt.imshow(np.transpose(img, (1, 2, 0)))  # convert from Tensor image
    
# obtain one batch of training images
dataiter = iter(train_loader)
images, labels = dataiter.next()
images = images.numpy() # convert images to numpy for display

# plot the images in the batch, along with the corresponding labels
fig = plt.figure(figsize=(10, 4))
# display 20 images
for idx in np.arange(10):
    ax = fig.add_subplot(2, 10/2, idx+1, xticks=[], yticks=[])
    imshow(images[idx])
    ax.set_title(classes[labels[idx]])

# %%
import torch.nn as nn
import torch.nn.functional as F
train_on_gpu = torch.cuda.is_available()
# define the CNN architecture
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        # convolutional layer
        self.conv1 = nn.Conv2d(3, 20, 5)   #Input = 224*224
        self.conv2 = nn.Conv2d(20, 32, 5)
        self.conv3 = nn.Conv2d(32, 60, 5)   #Input = 220*220
        self.conv4 = nn.Conv2d(60, 70, 5)
        
        # max pooling layer
        self.pool = nn.MaxPool2d(2, 2)     #Input = 216*216, output = 108*108
        
        self.dropout = nn.Dropout(0.2)
        
        self.fc1 = nn.Linear(70*10*10 , 500)  
        self.fc2 = nn.Linear(500, 200)
        self.fc3 = nn.Linear(200, 2)
        self.softmax = nn.LogSoftmax(dim=1)
        


        
    def forward(self, x):
        # add sequence of convolutional and max pooling layers
        x = self.pool(F.hardtanh(self.conv1(x))) # 224 -> 220 -> 110
        x = self.pool(F.hardtanh(self.conv2(x))) # 110 -> 106 -> 53
        x = self.pool(F.hardtanh(self.conv3(x))) # 53 -> 49 -> 24
        x = self.pool(F.hardtanh(self.conv4(x))) # 24 -> 20 -> 10
        x = self.dropout(x)
        x = x.view(-1, 70*10*10)   #32*53*53
        x = F.relu(self.fc1(x))
        x = self.dropout(F.hardtanh(self.fc2(x)))
        x = self.softmax(self.fc3(x))
        x = self.softmax(x)
        x = self.softmax(x)

        return x

# create a complete CNN
model = Net()
print(model)

# move tensors to GPU if CUDA is available
if train_on_gpu:
    model.cuda()
# Out:
# Net(
#   (conv1): Conv2d(3, 20, kernel_size=(5, 5), stride=(1, 1))
#   (conv2): Conv2d(20, 32, kernel_size=(5, 5), stride=(1, 1))
#   (conv3): Conv2d(32, 60, kernel_size=(5, 5), stride=(1, 1))
#   (conv4): Conv2d(60, 70, kernel_size=(5, 5), stride=(1, 1))
#   (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (dropout): Dropout(p=0.2)
#   (fc1): Linear(in_features=7000, out_features=500, bias=True)
#   (fc2): Linear(in_features=500, out_features=200, bias=True)
#   (fc3): Linear(in_features=200, out_features=2, bias=True)
#   (softmax): LogSoftmax()
# )

# %%
# Loss function
criterion = torch.nn.CrossEntropyLoss()
# Optimizer
optimizer = torch.optim.SGD(model.parameters(), lr = 0.003, momentum= 0.9)

# %%
# number of epochs to train the model
n_epochs = 400 # you may increase this number to train a final model

valid_loss_min = np.Inf # track change in validation loss

for epoch in range(1, n_epochs+1):

    # keep track of training and validation loss
    train_loss = 0.0
    valid_loss = 0.0
    
    ###################
    # train the model #
    ###################
    model.train()
    for data, target in train_loader:
        # move tensors to GPU if CUDA is available
        if train_on_gpu:
            data, target = data.cuda(), target.cuda()
        # clear the gradients of all optimized variables
        optimizer.zero_grad()
        # forward pass: compute predicted outputs by passing inputs to the model
        output = model(data)
        # calculate the batch loss
        loss = criterion(output, target)
        # backward pass: compute gradient of the loss with respect to model parameters
        loss.backward()
        # perform a single optimization step (parameter update)
        optimizer.step()
        # update training loss
        train_loss += loss.item()*data.size(0)
        
    ######################    
    # validate the model #
    ######################
    model.eval()
    for data, target in valid_loader:
        # move tensors to GPU if CUDA is available
        if train_on_gpu:
            data, target = data.cuda(), target.cuda()
        # forward pass: compute predicted outputs by passing inputs to the model
        output = model(data)
        # calculate the batch loss
        loss = criterion(output, target)
        # update average validation loss 
        valid_loss += loss.item()*data.size(0)
    
    # calculate average losses
    train_loss = train_loss/len(train_loader.dataset)
    valid_loss = valid_loss/len(valid_loader.dataset)
        
    # print training/validation statistics 
    print('Epoch: {} \tTraining Loss: {:.6f} \tValidation Loss: {:.6f}'.format(
        epoch, train_loss, valid_loss))
    
    # save model if validation loss has decreased
    if valid_loss <= valid_loss_min:
        print('Validation loss decreased ({:.6f} --> {:.6f}).  Saving model ...'.format(
        valid_loss_min,
        valid_loss))
        torch.save(model.state_dict(), 'model_cifar.pt')
        valid_loss_min = valid_loss
# Out:
# Epoch: 1 	Training Loss: 0.425382 	Validation Loss: 0.044852
# Validation loss decreased (inf --> 0.044852).  Saving model ...
# Epoch: 2 	Training Loss: 0.410508 	Validation Loss: 0.041651
# Validation loss decreased (0.044852 --> 0.041651).  Saving model ...
# Epoch: 3 	Training Loss: 0.395011 	Validation Loss: 0.038413
# Validation loss decreased (0.041651 --> 0.038413).  Saving model ...
# Epoch: 4 	Training Loss: 0.385026 	Validation Loss: 0.035989
# Validation loss decreased (0.038413 --> 0.035989).  Saving model ...
# Epoch: 5 	Training Loss: 0.382620 	Validation Loss: 0.034929
# Validation loss decreased (0.035989 --> 0.034929).  Saving model ...
# Epoch: 6 	Training Loss: 0.382521 	Validation Loss: 0.034919
# Validation loss decreased (0.034929 --> 0.034919).  Saving model ...
# Epoch: 7 	Training Loss: 0.382191 	Validation Loss: 0.035138
# Epoch: 8 	Training Loss: 0.382788 	Validation Loss: 0.035667
# Epoch: 9 	Training Loss: 0.382506 	Validation Loss: 0.035654
# Epoch: 10 	Training Loss: 0.382874 	Validation Loss: 0.035438
# Epoch: 11 	Training Loss: 0.383362 	Validation Loss: 0.035316
# Epoch: 12 	Training Loss: 0.382544 	Validation Loss: 0.035856
# Epoch: 13 	Training Loss: 0.382268 	Validation Loss: 0.035763
# Epoch: 14 	Training Loss: 0.382603 	Validation Loss: 0.035308
# Epoch: 15 	Training Loss: 0.382705 	Validation Loss: 0.035303
# Epoch: 16 	Training Loss: 0.383054 	Validation Loss: 0.035456
# Epoch: 17 	Training Loss: 0.382210 	Validation Loss: 0.035673
# Epoch: 18 	Training Loss: 0.382757 	Validation Loss: 0.035662
# Epoch: 19 	Training Loss: 0.382256 	Validation Loss: 0.035689
# Epoch: 20 	Training Loss: 0.382368 	Validation Loss: 0.035823
# Epoch: 21 	Training Loss: 0.382475 	Validation Loss: 0.035403
# Epoch: 22 	Training Loss: 0.382959 	Validation Loss: 0.035530
# Epoch: 23 	Training Loss: 0.383080 	Validation Loss: 0.035735
# Epoch: 24 	Training Loss: 0.382500 	Validation Loss: 0.035503
# Epoch: 25 	Training Loss: 0.382080 	Validation Loss: 0.035371
# Epoch: 26 	Training Loss: 0.383143 	Validation Loss: 0.035251
# Epoch: 27 	Training Loss: 0.382313 	Validation Loss: 0.035308
# Epoch: 28 	Training Loss: 0.383201 	Validation Loss: 0.035514
# Epoch: 29 	Training Loss: 0.382595 	Validation Loss: 0.035357
# Epoch: 30 	Training Loss: 0.383464 	Validation Loss: 0.035661
# Epoch: 31 	Training Loss: 0.383141 	Validation Loss: 0.035390
# Epoch: 32 	Training Loss: 0.382264 	Validation Loss: 0.035649
# Epoch: 33 	Training Loss: 0.382827 	Validation Loss: 0.035568
# Epoch: 34 	Training Loss: 0.381886 	Validation Loss: 0.035617
# Epoch: 35 	Training Loss: 0.382863 	Validation Loss: 0.035612
# Epoch: 36 	Training Loss: 0.382424 	Validation Loss: 0.035153
# Epoch: 37 	Training Loss: 0.382021 	Validation Loss: 0.035100
# Epoch: 38 	Training Loss: 0.383016 	Validation Loss: 0.035508
# Epoch: 39 	Training Loss: 0.382653 	Validation Loss: 0.035573
# Epoch: 40 	Training Loss: 0.382969 	Validation Loss: 0.035594
# Epoch: 41 	Training Loss: 0.382184 	Validation Loss: 0.035528
# Epoch: 42 	Training Loss: 0.382618 	Validation Loss: 0.035456
# Epoch: 43 	Training Loss: 0.382337 	Validation Loss: 0.035651
# Epoch: 44 	Training Loss: 0.383117 	Validation Loss: 0.035431
# Epoch: 45 	Training Loss: 0.382721 	Validation Loss: 0.035660
# Epoch: 46 	Training Loss: 0.382442 	Validation Loss: 0.035904
# Epoch: 47 	Training Loss: 0.382680 	Validation Loss: 0.035778
# Epoch: 48 	Training Loss: 0.382814 	Validation Loss: 0.035417
# Epoch: 49 	Training Loss: 0.382361 	Validation Loss: 0.035280
# Epoch: 50 	Training Loss: 0.382840 	Validation Loss: 0.035463
# Epoch: 51 	Training Loss: 0.382465 	Validation Loss: 0.035732
# Epoch: 52 	Training Loss: 0.381980 	Validation Loss: 0.035409
# Epoch: 53 	Training Loss: 0.382856 	Validation Loss: 0.035507
# Epoch: 54 	Training Loss: 0.382359 	Validation Loss: 0.035457
# Epoch: 55 	Training Loss: 0.382230 	Validation Loss: 0.035582
# Epoch: 56 	Training Loss: 0.381848 	Validation Loss: 0.035422
# Epoch: 57 	Training Loss: 0.382395 	Validation Loss: 0.035356
# Epoch: 58 	Training Loss: 0.383005 	Validation Loss: 0.035406
# Epoch: 59 	Training Loss: 0.382386 	Validation Loss: 0.035417
# Epoch: 60 	Training Loss: 0.382872 	Validation Loss: 0.035175
# Epoch: 61 	Training Loss: 0.381880 	Validation Loss: 0.035479
# Epoch: 62 	Training Loss: 0.382007 	Validation Loss: 0.035662
# Epoch: 63 	Training Loss: 0.382831 	Validation Loss: 0.035526
# Epoch: 64 	Training Loss: 0.381533 	Validation Loss: 0.035386
# Epoch: 65 	Training Loss: 0.383024 	Validation Loss: 0.035615
# Epoch: 66 	Training Loss: 0.381685 	Validation Loss: 0.035445
# Epoch: 67 	Training Loss: 0.382043 	Validation Loss: 0.035698

# %%
# track test loss
test_loss = 0.0
class_correct = list(0. for i in range(2))
class_total = list(0. for i in range(2))

model.eval()
i=1
# iterate over test data
len(test_loader)
for data, target in test_loader:
    i=i+1
    if len(target)!=batch_size:
        continue
        
    # move tensors to GPU if CUDA is available
    if train_on_gpu:
        data, target = data.cuda(), target.cuda()
    # forward pass: compute predicted outputs by passing inputs to the model
    output = model(data)
    # calculate the batch loss
    loss = criterion(output, target)
    # update test loss 
    test_loss += loss.item()*data.size(0)
    # convert output probabilities to predicted class
    _, pred = torch.max(output, 1)    
    # compare predictions to true label
    correct_tensor = pred.eq(target.data.view_as(pred))
    correct = np.squeeze(correct_tensor.numpy()) if not train_on_gpu else np.squeeze(correct_tensor.cpu().numpy())
    # calculate test accuracy for each object class
#     print(target)
    
    for i in range(batch_size):       
        label = target.data[i]
        class_correct[label] += correct[i].item()
        class_total[label] += 1

# average test loss
test_loss = test_loss/len(test_loader.dataset)
print('Test Loss: {:.6f}\n'.format(test_loss))

for i in range(2):
    if class_total[i] > 0:
        print('Test Accuracy of %5s: %2d%% (%2d/%2d)' % (
            classes[i], 100 * class_correct[i] / class_total[i],
            np.sum(class_correct[i]), np.sum(class_total[i])))
    else:
        print('Test Accuracy of %5s: N/A (no training examples)' % (classes[i]))

print('\nTest Accuracy (Overall): %2d%% (%2d/%2d)' % (
    100. * np.sum(class_correct) / np.sum(class_total),
    np.sum(class_correct), np.sum(class_total)))
