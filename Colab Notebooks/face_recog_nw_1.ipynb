# %%
! git clone https://Nusha:inceptionv3@gitlab.com/Nusha/abcdefghi
# Out:
# Cloning into 'abcdefghi'...
# warning: redirecting to https://gitlab.com/Nusha/abcdefghi.git/
# remote: Enumerating objects: 877, done.
# remote: Counting objects: 100% (877/877), done.
# remote: Compressing objects: 100% (876/876), done.
# remote: Total 877 (delta 0), reused 877 (delta 0)
# Receiving objects: 100% (877/877), 10.28 MiB | 14.52 MiB/s, done.

# %%
import torch
import numpy as np
from torchvision import datasets
import torchvision.transforms as transforms
from torch.utils.data.sampler import SubsetRandomSampler

# %%
# how many samples per batch to load
batch_size = 64
# percentage of training set to use as validation
test_size = 0.3
valid_size = 0.1

# convert data to a normalized torch.FloatTensor
transform = transforms.Compose([
    transforms.RandomHorizontalFlip(),
    transforms.RandomRotation(20),
    transforms.Resize(size=(224,224)),
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
    ])

data = datasets.ImageFolder('abcdefghi/data_die',transform=transform)

# %%
#For test
num_data = len(data)
indices_data = list(range(num_data))
np.random.shuffle(indices_data)
split_tt = int(np.floor(test_size * num_data))
train_idx, test_idx = indices_data[split_tt:], indices_data[:split_tt]

#For Valid
num_train = len(train_idx)
indices_train = list(range(num_train))
np.random.shuffle(indices_train)
split_tv = int(np.floor(valid_size * num_train))
train_new_idx, valid_idx = indices_train[split_tv:],indices_train[:split_tv]


# define samplers for obtaining training and validation batches
train_sampler = SubsetRandomSampler(train_new_idx)
test_sampler = SubsetRandomSampler(test_idx)
valid_sampler = SubsetRandomSampler(valid_idx)

train_loader = torch.utils.data.DataLoader(data, batch_size=batch_size,
    sampler=train_sampler, num_workers=1)
valid_loader = torch.utils.data.DataLoader(data, batch_size=batch_size, 
    sampler=valid_sampler, num_workers=1)
test_loader = torch.utils.data.DataLoader(data, sampler = test_sampler, batch_size=batch_size, 
    num_workers=1)
classes = [0,1]

# %%
len(test_loader)*batch_size + len(valid_loader)*batch_size + len(train_loader)*batch_size
for batch in valid_loader:
    print(batch[0].size())
# Out:
# torch.Size([61, 3, 224, 224])

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# helper function to un-normalize and display an image
def imshow(img):
    img = img / 2 + 0.5  # unnormalize
    plt.imshow(np.transpose(img, (1, 2, 0)))  # convert from Tensor image
    
# obtain one batch of training images
dataiter = iter(train_loader)
images, labels = dataiter.next()
images = images.numpy() # convert images to numpy for display

# plot the images in the batch, along with the corresponding labels
fig = plt.figure(figsize=(10, 4))
# display 20 images
for idx in np.arange(10):
    ax = fig.add_subplot(2, 10/2, idx+1, xticks=[], yticks=[])
    imshow(images[idx])
    ax.set_title(classes[labels[idx]])

# %%
import torch.nn as nn
import torch.nn.functional as F
train_on_gpu = torch.cuda.is_available()
# define the CNN architecture
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        # convolutional layer
        self.conv1 = nn.Conv2d(3, 16, 5)   #Input = 224*224
        self.conv2 = nn.Conv2d(16, 16, 5)
        self.conv3 = nn.Conv2d(16, 32, 5)   #Input = 220*220
        
        # max pooling layer
        self.pool = nn.MaxPool2d(2, 2)     #Input = 216*216, output = 108*108
        
        self.dropout = nn.Dropout(0.2)
        
        self.fc1 = nn.Linear(32*24*24 , 256)  
        self.fc2 = nn.Linear(256, 84)
        self.fc3 = nn.Linear(84, 2)
        self.softmax = nn.LogSoftmax(dim=1)
        


        
    def forward(self, x):
        # add sequence of convolutional and max pooling layers
        x = self.pool(F.relu(self.conv1(x)))# 224 -> 220 -> 110
        x = self.pool(F.relu(self.conv2(x))) # 110 -> 106 -> 53
        x = self.pool(F.relu(self.conv3(x))) #53 -> 49 -> 24.5
        x = self.dropout(x)
        x = x.view(-1, 32*24*24)   #32*53*53
        x = F.relu(self.fc1(x))
        x = self.dropout(F.relu(self.fc2(x)))
        x = self.softmax(self.fc3(x))

        return x

# create a complete CNN
model = Net()
print(model)

# move tensors to GPU if CUDA is available
if train_on_gpu:
    model.cuda()
# Out:
# Net(
#   (conv1): Conv2d(3, 16, kernel_size=(5, 5), stride=(1, 1))
#   (conv2): Conv2d(16, 16, kernel_size=(5, 5), stride=(1, 1))
#   (conv3): Conv2d(16, 32, kernel_size=(5, 5), stride=(1, 1))
#   (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (dropout): Dropout(p=0.2)
#   (fc1): Linear(in_features=18432, out_features=256, bias=True)
#   (fc2): Linear(in_features=256, out_features=84, bias=True)
#   (fc3): Linear(in_features=84, out_features=2, bias=True)
#   (softmax): LogSoftmax()
# )

# %%
# Loss function
criterion = torch.nn.CrossEntropyLoss()
# Optimizer
optimizer = torch.optim.SGD(model.parameters(), lr = 0.003, momentum= 0.9)

# %%
# number of epochs to train the model
n_epochs = 400 # you may increase this number to train a final model

valid_loss_min = np.Inf # track change in validation loss

for epoch in range(1, n_epochs+1):

    # keep track of training and validation loss
    train_loss = 0.0
    valid_loss = 0.0
    
    ###################
    # train the model #
    ###################
    model.train()
    for data, target in train_loader:
        # move tensors to GPU if CUDA is available
        if train_on_gpu:
            data, target = data.cuda(), target.cuda()
        # clear the gradients of all optimized variables
        optimizer.zero_grad()
        # forward pass: compute predicted outputs by passing inputs to the model
        output = model(data)
        # calculate the batch loss
        loss = criterion(output, target)
        # backward pass: compute gradient of the loss with respect to model parameters
        loss.backward()
        # perform a single optimization step (parameter update)
        optimizer.step()
        # update training loss
        train_loss += loss.item()*data.size(0)
        
    ######################    
    # validate the model #
    ######################
    model.eval()
    for data, target in valid_loader:
        # move tensors to GPU if CUDA is available
        if train_on_gpu:
            data, target = data.cuda(), target.cuda()
        # forward pass: compute predicted outputs by passing inputs to the model
        output = model(data)
        # calculate the batch loss
        loss = criterion(output, target)
        # update average validation loss 
        valid_loss += loss.item()*data.size(0)
    
    # calculate average losses
    train_loss = train_loss/len(train_loader.dataset)
    valid_loss = valid_loss/len(valid_loader.dataset)
        
    # print training/validation statistics 
    print('Epoch: {} \tTraining Loss: {:.6f} \tValidation Loss: {:.6f}'.format(
        epoch, train_loss, valid_loss))
    
    # save model if validation loss has decreased
    if valid_loss <= valid_loss_min:
        print('Validation loss decreased ({:.6f} --> {:.6f}).  Saving model ...'.format(
        valid_loss_min,
        valid_loss))
        torch.save(model.state_dict(), 'model_cifar.pt')
        valid_loss_min = valid_loss
# Out:
# Epoch: 1 	Training Loss: 0.421333 	Validation Loss: 0.045247
# Validation loss decreased (inf --> 0.045247).  Saving model ...
# Epoch: 2 	Training Loss: 0.403782 	Validation Loss: 0.043076
# Validation loss decreased (0.045247 --> 0.043076).  Saving model ...
# Epoch: 3 	Training Loss: 0.386798 	Validation Loss: 0.040987
# Validation loss decreased (0.043076 --> 0.040987).  Saving model ...
# Epoch: 4 	Training Loss: 0.378718 	Validation Loss: 0.040241
# Validation loss decreased (0.040987 --> 0.040241).  Saving model ...
# Epoch: 5 	Training Loss: 0.379568 	Validation Loss: 0.040280
# Epoch: 6 	Training Loss: 0.377595 	Validation Loss: 0.040289
# Epoch: 7 	Training Loss: 0.376459 	Validation Loss: 0.040367
# Epoch: 8 	Training Loss: 0.378810 	Validation Loss: 0.040296
# Epoch: 9 	Training Loss: 0.376937 	Validation Loss: 0.040434
# Epoch: 10 	Training Loss: 0.377514 	Validation Loss: 0.040354
# Epoch: 11 	Training Loss: 0.377709 	Validation Loss: 0.040331
# Epoch: 12 	Training Loss: 0.378780 	Validation Loss: 0.040397
# Epoch: 13 	Training Loss: 0.377046 	Validation Loss: 0.040409
# Epoch: 14 	Training Loss: 0.379037 	Validation Loss: 0.040399
# Epoch: 15 	Training Loss: 0.379126 	Validation Loss: 0.040287
# Epoch: 16 	Training Loss: 0.376871 	Validation Loss: 0.040462
# Epoch: 17 	Training Loss: 0.378209 	Validation Loss: 0.040319
# Epoch: 18 	Training Loss: 0.379200 	Validation Loss: 0.040406
# Epoch: 19 	Training Loss: 0.377020 	Validation Loss: 0.040350
# Epoch: 20 	Training Loss: 0.377791 	Validation Loss: 0.040329
# Epoch: 21 	Training Loss: 0.379536 	Validation Loss: 0.040444
# Epoch: 22 	Training Loss: 0.378922 	Validation Loss: 0.040434
# Epoch: 23 	Training Loss: 0.377815 	Validation Loss: 0.040346
# Epoch: 24 	Training Loss: 0.377308 	Validation Loss: 0.040338
# Epoch: 25 	Training Loss: 0.378465 	Validation Loss: 0.040344
# Epoch: 26 	Training Loss: 0.377361 	Validation Loss: 0.040317
# Epoch: 27 	Training Loss: 0.377233 	Validation Loss: 0.040381
# Epoch: 365 	Training Loss: 0.057743 	Validation Loss: 0.114953
# Epoch: 366 	Training Loss: 0.044680 	Validation Loss: 0.133765
# Epoch: 367 	Training Loss: 0.052916 	Validation Loss: 0.127951
# Epoch: 368 	Training Loss: 0.054901 	Validation Loss: 0.125313
# Epoch: 369 	Training Loss: 0.043512 	Validation Loss: 0.121612
# Epoch: 370 	Training Loss: 0.055977 	Validation Loss: 0.092416
# Epoch: 371 	Training Loss: 0.049160 	Validation Loss: 0.125023
# Epoch: 372 	Training Loss: 0.048251 	Validation Loss: 0.120592
# Epoch: 373 	Training Loss: 0.051490 	Validation Loss: 0.103477
# Epoch: 374 	Training Loss: 0.045628 	Validation Loss: 0.161348
# Epoch: 375 	Training Loss: 0.064804 	Validation Loss: 0.147194
# Epoch: 376 	Training Loss: 0.052680 	Validation Loss: 0.135150
# Epoch: 377 	Training Loss: 0.049795 	Validation Loss: 0.142746
# Epoch: 378 	Training Loss: 0.058481 	Validation Loss: 0.140200
# Epoch: 379 	Training Loss: 0.066373 	Validation Loss: 0.130345
# Epoch: 380 	Training Loss: 0.051881 	Validation Loss: 0.129840
# Epoch: 381 	Training Loss: 0.040492 	Validation Loss: 0.094328
# Epoch: 382 	Training Loss: 0.055256 	Validation Loss: 0.102143
# Epoch: 383 	Training Loss: 0.037986 	Validation Loss: 0.134525
# Epoch: 384 	Training Loss: 0.041884 	Validation Loss: 0.120292
# Epoch: 385 	Training Loss: 0.030604 	Validation Loss: 0.123100
# Epoch: 386 	Training Loss: 0.057067 	Validation Loss: 0.147644
# Epoch: 387 	Training Loss: 0.044884 	Validation Loss: 0.151601
# Epoch: 388 	Training Loss: 0.059350 	Validation Loss: 0.150585
# Epoch: 389 	Training Loss: 0.065239 	Validation Loss: 0.124446
# Epoch: 390 	Training Loss: 0.071439 	Validation Loss: 0.138016
# Epoch: 391 	Training Loss: 0.066205 	Validation Loss: 0.092460
# Epoch: 392 	Training Loss: 0.065887 	Validation Loss: 0.127808
# Epoch: 393 	Training Loss: 0.040227 	Validation Loss: 0.137249
# Epoch: 394 	Training Loss: 0.052070 	Validation Loss: 0.120975
# Epoch: 395 	Training Loss: 0.044278 	Validation Loss: 0.118364
# Epoch: 396 	Training Loss: 0.023141 	Validation Loss: 0.136953
# Epoch: 397 	Training Loss: 0.039512 	Validation Loss: 0.136650
# Epoch: 398 	Training Loss: 0.034488 	Validation Loss: 0.141818
# Epoch: 399 	Training Loss: 0.056656 	Validation Loss: 0.156946
# Epoch: 400 	Training Loss: 0.034801 	Validation Loss: 0.125262

# %%
# track test loss
test_loss = 0.0
class_correct = list(0. for i in range(2))
class_total = list(0. for i in range(2))

print('\n')
print(n_epochs)

model.eval()
i=1
# iterate over test data
len(test_loader)
for data, target in test_loader:
    i=i+1
    if len(target)!=batch_size:
        continue
        
    # move tensors to GPU if CUDA is available
    if train_on_gpu:
        data, target = data.cuda(), target.cuda()
    # forward pass: compute predicted outputs by passing inputs to the model
    output = model(data)
    # calculate the batch loss
    loss = criterion(output, target)
    # update test loss 
    test_loss += loss.item()*data.size(0)
    # convert output probabilities to predicted class
    _, pred = torch.max(output, 1)    
    # compare predictions to true label
    correct_tensor = pred.eq(target.data.view_as(pred))
    correct = np.squeeze(correct_tensor.numpy()) if not train_on_gpu else np.squeeze(correct_tensor.cpu().numpy())
    # calculate test accuracy for each object class
#     print(target)
    
    for i in range(batch_size):       
        label = target.data[i]
        class_correct[label] += correct[i].item()
        class_total[label] += 1

# average test loss
test_loss = test_loss/len(test_loader.dataset)
print('Test Loss: {:.6f}\n'.format(test_loss))

for i in range(2):
    if class_total[i] > 0:
        print('Test Accuracy of %5s: %2d%% (%2d/%2d)' % (
            classes[i], 100 * class_correct[i] / class_total[i],
            np.sum(class_correct[i]), np.sum(class_total[i])))
    else:
        print('Test Accuracy of %5s: N/A (no training examples)' % (classes[i]))

print('\nTest Accuracy (Overall): %2d%% (%2d/%2d)' % (
    100. * np.sum(class_correct) / np.sum(class_total),
    np.sum(class_correct), np.sum(class_total)))
# Out:
# 400
# Test Loss: 0.444902
#
# Test Accuracy of     0: 95% (126/132)
# Test Accuracy of     1: 50% (63/124)
#
# Test Accuracy (Overall): 73% (189/256)
